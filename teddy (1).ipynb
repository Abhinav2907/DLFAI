# %%
# !git clone https://github.com/fastai/course-v3
from pathlib import Path
from PIL import Image

data_folder = Path("course-v3/nbs/dl1/images/notebook_tutorial/")

file_to_open = data_folder / "cat_example.jpg"

Image.open(file_to_open)
# Out:
# Cloning into 'course-v3'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 3726 (delta 2), reused 0 (delta 0), pack-reused 3718
# Receiving objects: 100% (3726/3726), 196.65 MiB | 31.57 MiB/s, done.
# Resolving deltas: 100% (2069/2069), done.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=394x500 at 0x7F041D697EF0>

# %%
from fastai.vision import *

# %% [markdown]
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n'))); in javascript prompt(ctrl+shift+j)

# %% [markdown]
# **or drag this to bookmark bar**
# javascript:document.body.innerHTML = `<a href="data:text/csv;charset=utf-8,${escape(Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou).join('\n'))}" download="links.csv">download urls</a>`;

# %%
folder = 'black'
file = 'bla.txt'

# %%
folder = 'teddys'
file = 'vsds.txt'

# %%
folder = 'grizzly'
file = 'gri.txt'

# %%
path = Path('data/bears')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
classes = ['teddys','grizzly','black']

# %%
download_images(path/folder/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:04<00:00]
#     </div>

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# teddys
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='102' class='' max='102', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [102/102 00:02<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000027.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000039.jpg'>
# Image data/bears/teddys/00000069.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000015.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000062.jpeg'>
# cannot identify image file <_io.BufferedReader name='data/bears/teddys/00000088.jpg'>
# grizzly
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='99', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [99/99 00:02<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='data/bears/grizzly/00000096.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/grizzly/00000064.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/grizzly/00000095.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/grizzly/00000056.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/grizzly/00000089.jpg'>
# black
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:02<00:00]
#     </div>
# Image data/bears/black/00000003.gif has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/bears/black/00000006.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/black/00000039.png'>
# cannot identify image file <_io.BufferedReader name='data/bears/black/00000016.jpg'>
# cannot identify image file <_io.BufferedReader name='data/bears/black/00000078.jpg'>

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['black', 'grizzly', 'teddys']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['black', 'grizzly', 'teddys'], 3, 228, 57)

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 00:21 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.199166</th>
#     <th>0.457352</th>
#     <th>0.228070</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.713661</th>
#     <th>0.065329</th>
#     <th>0.017544</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.497801</th>
#     <th>0.055406</th>
#     <th>0.035088</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.379922</th>
#     <th>0.054705</th>
#     <th>0.035088</th>
#   </tr>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()
# Out:
# Min numerical gradient: 6.31E-07

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))
# Out:
# Total time: 00:10 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.055141</th>
#     <th>0.104472</th>
#     <th>0.035088</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.068020</th>
#     <th>0.090494</th>
#     <th>0.035088</th>
#   </tr>
# </table>

# %%
learn.save('stage-2')

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
from fastai.widgets import *

# %% [markdown]
# try cleaning train and test as well

# %%
losses,idxs=interp.top_losses()
top_loss_paths=data.valid_ds.x[idxs]

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Valid)

# %%
5*8
# Out:
# 40

# %%
learn.export()

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'black'/'00000041.jpg')
img
# Out:
# Image (3, 294, 500)

# %%
learn = load_learner(path)

# %%
path
# Out:
# PosixPath('data/bears')

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category black

# %%
5+5
# Out:
# 10

# %%
8/8
# Out:
# 1.0

# %%
5*5
# Out:
# 25

# %%
learn.predict??
